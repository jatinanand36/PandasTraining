# %%
import pandas as pd
import numpy as np

# %%
DF=pd.DataFrame(np.random.randn(10,4),index=pd.date_range('4/4/2019',periods=10),columns=list('ABCD'))

# %%
DF
# Out:
#                    A         B         C         D
# 2019-04-04 -0.501455  2.282150  0.602115  0.537158
# 2019-04-05 -0.490300 -0.039048  0.634291 -0.194076
# 2019-04-06 -0.221319 -0.363794 -0.462705  0.479218
# 2019-04-07  1.394918 -1.043535 -1.007619  2.253580
# 2019-04-08 -1.027913 -0.175219 -0.683315  0.686699
# 2019-04-09 -0.074710  0.429135  0.625275 -0.769648
# 2019-04-10 -1.163763  0.276887 -0.155892 -0.813401
# 2019-04-11 -1.254580  0.628254  0.556290 -0.520639
# 2019-04-12 -0.206085  0.647658 -0.049314 -1.233087
# 2019-04-13  1.276391 -0.451084 -0.092416 -0.131826

# %%
DF.plot()

# %%
DF.plot.bar()

# %%
DF.plot.bar(stacked=True)

# %%
DF.plot.barh()

# %%
DF.plot.box()

# %%
DF.plot.barh(stacked=True)

# %%
DF.plot.hist()

# %%
DF.plot.hist(bins=20)

# %%
DF2=pd.DataFrame({'a':np.random.randn(1000)+1,'b':np.random.randn(1000),'c':
np.random.randn(1000) - 1}, columns=['a', 'b', 'c'])
DF2.plot.hist(bins=20)

# %%
DF3 = pd.DataFrame(np.random.rand(10,3),columns=['A','B','C'])

# %%
DF3
# Out:
#           A         B         C
# 0  0.935714  0.897525  0.778371
# 1  0.665756  0.177399  0.857493
# 2  0.512214  0.047369  0.604332
# 3  0.981448  0.823549  0.539829
# 4  0.705184  0.509533  0.879361
# 5  0.288620  0.983648  0.257287
# 6  0.130652  0.185162  0.241110
# 7  0.201985  0.358084  0.680777
# 8  0.632640  0.308148  0.726199
# 9  0.731371  0.655436  0.570616

# %%
DF3.plot.area()

# %%
DF3.plot.scatter(x='A',y='B')

# %%
DF4 = pd.DataFrame(3* np.random.rand(4),index=['A','B','C','D'],columns=['X'])
# DF3.plot.pie(subplots=True)

# %%
DF4
# Out:
#           X
# A  2.318256
# B  2.977004
# C  0.832696
# D  0.531206

# %%
DF4.plot.pie(subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x11b7d8630>],
#       dtype=object)
